# %% [markdown]
# # Imports

# %% [markdown]
# # Variables

# %%
simplecnn_model_performance = "../fgn/without_clip/simplecnn/fedavg_random_criticalfl_battery_False_dataset_cifar10_dir_0.1_seed_1/model_performance.json"

# %% [markdown]
# # Aux Functions

# %% [markdown]
# # Processing
